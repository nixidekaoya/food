# %%
import torch
import pandas as pd
import numpy as np
import random
import itertools
import math
import os
import run

#Constant
ADAM = "Adam"
SGD = "SGD"
L0 = "L0"
L1 = "L1"
L2 = "L2"
MSE = "MSE"
CEL = "CEL"
WD = "0005"
ATTENTION = "attention_net"
LINEAR = "linear_net"
LINEAR_NOHIDDEN = "linear_no_hidden_net"
RELU = "relu"
SIGMOID = "sigmoid"



# %matplotlib inline
# %pwd
# Out:
# '/home/li/food'

# %%
####################### Real Data Number 1000 Epoch 500 QUERY_1_9


## TRAIN PARAMS
NET = ATTENTION
BATCH_SIZE = 10
LEARNING_RATE = 0.01
WEIGHT_DECAY = 0.001
QUERY_DIM = 9
KEY_DIM = 5
K_FOLDER = 5
FEATURE_DIM = 32
EPOCH = 300
MOMENTUM = 0.9
REG = L2
ACT = SIGMOID
OPTIMIZER = SGD
BETAS = (0.9,0.999)
LOSS = CEL
MASK = True


## SETTING PARAMS
MODE = "CV"
ARTIFICIAL = False
BatchNorm = True
ATTENTION_REG = True
ATTENTION_REG_WEIGHT = 0.1
w_f = "FIXED"
w_f_type = "Eye"
username = "li_mofei"
WD = "0005"
DATE = "20191104"

input_csv = "/home/li/food/data/20190922_limofei_1000_input.csv"
output_csv = "/home/li/food/data/20190922_limofei_1000_output.csv"
weight_csv = "/home/li/food/artificial_data/Artificial_20191016_ITEM_NO_32_CLASS_NO_2_DATA_NO_100000_CHOICE_NO_4weights.csv"

attention_reg_weight_list = [0.05,0.01,0.005,0.001,0.0005,0.0001]

for q in attention_reg_weight_list:
    ATTENTION_REG_WEIGHT = q
    
    print("ATTENTION_REG_WEIGHT: " + str(ATTENTION_REG_WEIGHT))
    run.run(input_csv = input_csv,
            output_csv = output_csv,
            weight_csv = weight_csv,
            mode = MODE,
            ATTENTION_REG = ATTENTION_REG,
            ATTENTION_REG_WEIGHT = ATTENTION_REG_WEIGHT,
            BATCH_NORM = BatchNorm,
            K_FOLDER = K_FOLDER,
            username = username,
            Q = QUERY_DIM,
            K = KEY_DIM,
            F = FEATURE_DIM,
            EPOCH = EPOCH,
            ARTIFICIAL = ARTIFICIAL,
            w_f = w_f,
            w_f_type = w_f_type,
            REG = REG,
            WEIGHT_DECAY = WEIGHT_DECAY,
            DATE = DATE,
            BATCH_SIZE = BATCH_SIZE,
            WD = WD,
            NET = NET
           )
# Out:
# ATTENTION_REG_WEIGHT: 0.5
# (1000, 65)
# (1000, 33)
# /home/li/food/artificial_data/Artificial_20191016_ITEM_NO_32_CLASS_NO_2_DATA_NO_100000_CHOICE_NO_4weights.csv
# 800
# 200
# (200, 200, 200, 200, 200)
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_0initial.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_1initial.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_2initial.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_3initial.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_4initial.model
# /home/li/food/neural_network.py:68: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(self.linear_layer1.weight)
# /home/li/food/neural_network.py:70: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   init.normal(self.linear_layer1.bias, mean = 0, std = 1)
# Epoch: 0 , CV_Model: 0 , Train Accuracy: 0.22375 , Test Accuracy: 0.185
# Epoch: 0 , CV_Model: 1 , Train Accuracy: 0.23375 , Test Accuracy: 0.25
# Epoch: 0 , CV_Model: 2 , Train Accuracy: 0.27875 , Test Accuracy: 0.3
# Epoch: 0 , CV_Model: 3 , Train Accuracy: 0.225 , Test Accuracy: 0.175
# Epoch: 0 , CV_Model: 4 , Train Accuracy: 0.24875 , Test Accuracy: 0.31
# Epoch: 50 , CV_Model: 0 , Train Accuracy: 0.4475 , Test Accuracy: 0.37
# Epoch: 50 , CV_Model: 1 , Train Accuracy: 0.42875 , Test Accuracy: 0.385
# Epoch: 50 , CV_Model: 2 , Train Accuracy: 0.425 , Test Accuracy: 0.365
# Epoch: 50 , CV_Model: 3 , Train Accuracy: 0.4275 , Test Accuracy: 0.355
# Epoch: 50 , CV_Model: 4 , Train Accuracy: 0.42375 , Test Accuracy: 0.39
# Epoch: 100 , CV_Model: 0 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 100 , CV_Model: 1 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 100 , CV_Model: 2 , Train Accuracy: 0.45375 , Test Accuracy: 0.32
# Epoch: 100 , CV_Model: 3 , Train Accuracy: 0.44125 , Test Accuracy: 0.37
# Epoch: 100 , CV_Model: 4 , Train Accuracy: 0.43875 , Test Accuracy: 0.375
# Epoch: 150 , CV_Model: 0 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 150 , CV_Model: 1 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 150 , CV_Model: 2 , Train Accuracy: 0.45625 , Test Accuracy: 0.33
# Epoch: 150 , CV_Model: 3 , Train Accuracy: 0.445 , Test Accuracy: 0.36
# Epoch: 150 , CV_Model: 4 , Train Accuracy: 0.46625 , Test Accuracy: 0.35
# Epoch: 200 , CV_Model: 0 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 200 , CV_Model: 1 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 200 , CV_Model: 2 , Train Accuracy: 0.465 , Test Accuracy: 0.355
# Epoch: 200 , CV_Model: 3 , Train Accuracy: 0.4425 , Test Accuracy: 0.36
# Epoch: 200 , CV_Model: 4 , Train Accuracy: 0.47125 , Test Accuracy: 0.355
# Epoch: 250 , CV_Model: 0 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 250 , CV_Model: 1 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 250 , CV_Model: 2 , Train Accuracy: 0.45875 , Test Accuracy: 0.35
# Epoch: 250 , CV_Model: 3 , Train Accuracy: 0.4475 , Test Accuracy: 0.365
# Epoch: 250 , CV_Model: 4 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 299 , CV_Model: 0 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 299 , CV_Model: 1 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 299 , CV_Model: 2 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# Epoch: 299 , CV_Model: 3 , Train Accuracy: 0.44125 , Test Accuracy: 0.36
# Epoch: 299 , CV_Model: 4 , Train Accuracy: 0.0 , Test Accuracy: 0.0
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_0.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_1.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_2.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_3.model
# /home/li/food/model/20191104/CV_20191104_Epoch_300_Net_attention_net_u_li_mofei_Q_9_K_5_F_32_REG_L2_ACT_sigmoid_WD_0005w_fEye_CV_Model_4.model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-b3e8765dc044> in <module>
#      64             BATCH_SIZE = BATCH_SIZE,
#      65             WD = WD,
# ---> 66             NET = NET
#      67            )
#
# ~/food/run.py in run(input_csv, output_csv, weight_csv, mode, username, ARTIFICIAL, K_FOLDER, DATE, MOMENTUM, EPOCH, BATCH_NORM, K, F, Q, REG, LEARNING_RATE, WEIGHT_DECAY, LOSS, ACT, BATCH_SIZE, OPTIMIZER, NET, w_f, w_f_type, VALIDATE_NUMBER, WD, extra_msg, ATTENTION_REG, ATTENTION_REG_WEIGHT)
#     858         VALIDATE_NUMBER = VALIDATE_NUMBER,
#     859         WD = WD,
# --> 860         extra_msg = extra_msg
#     861         )
#     862
#
# ~/food/run.py in run_cross_validation(input_csv, output_csv, weight_csv, username, K_FOLDER, BATCH_NORM, MOMENTUM, ARTIFICIAL, DATE, EPOCH, KEY_DIM, FEATURE_DIM, QUERY_DIM, REG, LEARNING_RATE, WEIGHT_DECAY, LOSS, ACT, BATCH_SIZE, OPTIMIZER, NET, w_f, w_f_type, VALIDATE_NUMBER, WD, extra_msg, ATTENTION_REG, ATTENTION_REG_WEIGHT)
#     732
#     733         pca = PCA(n_components = 2)
# --> 734         pca.fit(valid_dist_list)
#     735         valid_feature = pca.transform(valid_dist_list)
#     736         print("Model " + str(k))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/pca.py in fit(self, X, y)
#     338             Returns the instance itself.
#     339         """
# --> 340         self._fit(X)
#     341         return self
#     342
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     379
#     380         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 381                         copy=self.copy)
#     382
#     383         # Handle n_components==None
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
